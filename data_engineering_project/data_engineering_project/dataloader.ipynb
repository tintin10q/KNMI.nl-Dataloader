# %%
# noinspection JupyterPackage
print("Hi")
# Out:
# Hi

# %%
import nctoolkit as nc

# %%
# Nc has a cool open url

# %%
try:
    ds = nc.open_data("KMDS__OPER_P___10M_OBS_L2_202405171530.nc")
except:
    print("Nope")
# Out:
# Nope

# %%
import netCDF4

# %%
db = netCDF4.Dataset("KMDS__OPER_P___10M_OBS_L2_202405161720.nc")
# print(db)
# print(db.name)
# print(db.ncattrs())
# db.close()

# %%
print(db.dimensions)
name = "time"
print("Time:", db[name][0])
print(db.ncattrs())
print(db.featureType)
print(db.groups)
print(db.variables.keys())
# Out:
# {'station': <class 'netCDF4._netCDF4.Dimension'>: name = 'station', size = 69, 'time': <class 'netCDF4._netCDF4.Dimension'>: name = 'time', size = 1}
# Time: 2347032000.0
# ['featureType', 'Conventions', 'title', 'institution', 'source', 'history', 'references', 'comment']
# timeSeries
# {}
# dict_keys(['station', 'time', 'wsi', 'stationname', 'lat', 'lon', 'height', 'D1H', 'dd', 'dn', 'dr', 'dsd', 'dx', 'ff', 'ffs', 'fsd', 'fx', 'fxs', 'gff', 'gffs', 'h', 'h1', 'h2', 'h3', 'hc', 'hc1', 'hc2', 'hc3', 'n', 'n1', 'n2', 'n3', 'nc', 'nc1', 'nc2', 'nc3', 'p0', 'pp', 'pg', 'pr', 'ps', 'pwc', 'Q1H', 'Q24H', 'qg', 'qgn', 'qgx', 'qnh', 'R12H', 'R1H', 'R24H', 'R6H', 'rg', 'rh', 'rh10', 'Sav1H', 'Sax1H', 'Sax3H', 'Sax6H', 'sq', 'ss', 'Sx1H', 'Sx3H', 'Sx6H', 't10', 'ta', 'tb', 'tb1', 'Tb1n6', 'Tb1x6', 'tb2', 'Tb2n6', 'Tb2x6', 'tb3', 'tb4', 'tb5', 'td', 'td10', 'tg', 'tgn', 'Tgn12', 'Tgn14', 'Tgn6', 'tn', 'Tn12', 'Tn14', 'Tn6', 'tsd', 'tx', 'Tx12', 'Tx24', 'Tx6', 'vv', 'W10', 'W10-10', 'ww', 'ww-10', 'zm', 'iso_dataset', 'product', 'projection', 'nhc', 'za'])

# %%
import glob
from collections import defaultdict

counts = defaultdict(int)

for file in glob.glob("*.nc"):
    db = netCDF4.Dataset("KMDS__OPER_P___10M_OBS_L2_202405161720.nc")
    for key in db.variables.keys():
        counts[key] += 1
    db.close()
    
print(counts)

# "Yeeeh its all the same!
# Out:
# defaultdict(<class 'int'>, {'station': 82, 'time': 82, 'wsi': 82, 'stationname': 82, 'lat': 82, 'lon': 82, 'height': 82, 'D1H': 82, 'dd': 82, 'dn': 82, 'dr': 82, 'dsd': 82, 'dx': 82, 'ff': 82, 'ffs': 82, 'fsd': 82, 'fx': 82, 'fxs': 82, 'gff': 82, 'gffs': 82, 'h': 82, 'h1': 82, 'h2': 82, 'h3': 82, 'hc': 82, 'hc1': 82, 'hc2': 82, 'hc3': 82, 'n': 82, 'n1': 82, 'n2': 82, 'n3': 82, 'nc': 82, 'nc1': 82, 'nc2': 82, 'nc3': 82, 'p0': 82, 'pp': 82, 'pg': 82, 'pr': 82, 'ps': 82, 'pwc': 82, 'Q1H': 82, 'Q24H': 82, 'qg': 82, 'qgn': 82, 'qgx': 82, 'qnh': 82, 'R12H': 82, 'R1H': 82, 'R24H': 82, 'R6H': 82, 'rg': 82, 'rh': 82, 'rh10': 82, 'Sav1H': 82, 'Sax1H': 82, 'Sax3H': 82, 'Sax6H': 82, 'sq': 82, 'ss': 82, 'Sx1H': 82, 'Sx3H': 82, 'Sx6H': 82, 't10': 82, 'ta': 82, 'tb': 82, 'tb1': 82, 'Tb1n6': 82, 'Tb1x6': 82, 'tb2': 82, 'Tb2n6': 82, 'Tb2x6': 82, 'tb3': 82, 'tb4': 82, 'tb5': 82, 'td': 82, 'td10': 82, 'tg': 82, 'tgn': 82, 'Tgn12': 82, 'Tgn14': 82, 'Tgn6': 82, 'tn': 82, 'Tn12': 82, 'Tn14': 82, 'Tn6': 82, 'tsd': 82, 'tx': 82, 'Tx12': 82, 'Tx24': 82, 'Tx6': 82, 'vv': 82, 'W10': 82, 'W10-10': 82, 'ww': 82, 'ww-10': 82, 'zm': 82, 'iso_dataset': 82, 'product': 82, 'projection': 82, 'nhc': 82, 'za': 82})

# %%
name = "time"

db = netCDF4.Dataset("KMDS__OPER_P___10M_OBS_L2_202405161720.nc")
print(len(db.variables[name]))
print(dir(db.variables[name]))
print(db.variables[name].shape)
# Out:
# 1
# ['__array__', '__class__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', '_assign_vlen', '_check_safecast', '_cmptype', '_enumtype', '_get', '_getdims', '_getname', '_grp', '_grpid', '_has_lsd', '_iscompound', '_isenum', '_isprimitive', '_isvlen', '_name', '_ncstring_attrs__', '_nunlimdim', '_pack', '_put', '_toma', '_use_get_vars', '_varid', '_vltype', 'always_mask', 'assignValue', 'chartostring', 'chunking', 'datatype', 'delncattr', 'dimensions', 'dtype', 'endian', 'filters', 'getValue', 'get_dims', 'get_var_chunk_cache', 'getncattr', 'group', 'long_name', 'mask', 'name', 'ncattrs', 'ndim', 'quantization', 'renameAttribute', 'scale', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_collective', 'set_ncstring_attrs', 'set_var_chunk_cache', 'setncattr', 'setncattr_string', 'setncatts', 'shape', 'size', 'standard_name', 'units', 'use_nc_get_vars']
# (1,)

# %%
from tqdm import tqdm
def iter_nc_files():
    for file in glob.iglob("*.nc"):
        db = netCDF4.Dataset(file)
        try:
            yield db
        finally:
            db.close()


counts = defaultdict(int)
file_count = 0
for db in iter_nc_files():
    for key in db.variables:
        counts[key] += 1
    file_count += 1
print(f"Iterated over {file_count} files. ")
print(f"There are {len(counts)} different keys with all the files")
print(f"Each key appearance counts:", counts)
# Out:
# Iterated over 85 files.
# There are 103 different keys with all the files
# Each key appearance counts: defaultdict(<class 'int'>, {'station': 85, 'time': 85, 'wsi': 85, 'stationname': 85, 'lat': 85, 'lon': 85, 'height': 85, 'D1H': 85, 'dd': 85, 'dn': 85, 'dr': 85, 'dsd': 85, 'dx': 85, 'ff': 85, 'ffs': 85, 'fsd': 85, 'fx': 85, 'fxs': 85, 'gff': 85, 'gffs': 85, 'h': 85, 'h1': 85, 'h2': 85, 'h3': 85, 'hc': 85, 'hc1': 85, 'hc2': 85, 'hc3': 85, 'n': 85, 'n1': 85, 'n2': 85, 'n3': 85, 'nc': 85, 'nc1': 85, 'nc2': 85, 'nc3': 85, 'p0': 85, 'pp': 85, 'pg': 85, 'pr': 85, 'ps': 85, 'pwc': 85, 'Q1H': 85, 'Q24H': 85, 'qg': 85, 'qgn': 85, 'qgx': 85, 'qnh': 85, 'R12H': 85, 'R1H': 85, 'R24H': 85, 'R6H': 85, 'rg': 85, 'rh': 85, 'rh10': 85, 'Sav1H': 85, 'Sax1H': 85, 'Sax3H': 85, 'Sax6H': 85, 'sq': 85, 'ss': 85, 'Sx1H': 85, 'Sx3H': 85, 'Sx6H': 85, 't10': 85, 'ta': 85, 'tb': 85, 'tb1': 85, 'Tb1n6': 85, 'Tb1x6': 85, 'tb2': 85, 'Tb2n6': 85, 'Tb2x6': 85, 'tb3': 85, 'tb4': 85, 'tb5': 85, 'td': 85, 'td10': 85, 'tg': 85, 'tgn': 85, 'Tgn12': 85, 'Tgn14': 85, 'Tgn6': 85, 'tn': 85, 'Tn12': 85, 'Tn14': 85, 'Tn6': 85, 'tsd': 85, 'tx': 85, 'Tx12': 85, 'Tx24': 85, 'Tx6': 85, 'vv': 85, 'W10': 85, 'W10-10': 85, 'ww': 85, 'ww-10': 85, 'zm': 85, 'iso_dataset': 85, 'product': 85, 'projection': 85, 'nhc': 85, 'za': 85})

# %%
db.variables
# Out:
# {'station': <class 'netCDF4._netCDF4.Variable'>
#  vlen station(station)
#      long_name: Station id
#      cf_role: timeseries_id
#  vlen data type: <class 'str'>
#  unlimited dimensions:
#  current shape = (69,),
#  'time': <class 'netCDF4._netCDF4.Variable'>
#  float64 time(time)
#      long_name: time of measurement
#      standard_name: time
#      units: seconds since 1950-01-01 00:00:00
#  unlimited dimensions:
#  current shape = (1,)
#  filling on, default _FillValue of 9.969209968386869e+36 used,
#  'wsi': <class 'netCDF4._netCDF4.Variable'>
#  vlen wsi(station)
#      long_name: Station wsi
#  vlen data type: <class 'str'>
#  unlimited dimensions:
#  current shape = (69,),
#  'stationname': <class 'netCDF4._netCDF4.Variable'>
#  vlen stationname(station)
#      long_name: Station name
#  vlen data type: <class 'str'>
#  unlimited dimensions:
#  current shape = (69,),
#  'lat': <class 'netCDF4._netCDF4.Variable'>
#  float64 lat(station)
#      long_name: station  latitude
#      standard_name: latitude
#      units: degrees_north
#  unlimited dimensions:
#  current shape = (69,)
#  filling on, default _FillValue of 9.969209968386869e+36 used,
#  'lon': <class 'netCDF4._netCDF4.Variable'>
#  float64 lon(station)
#      long_name: station longitude
#      standard_name: longitude
#      units: degrees_east
#  unlimited dimensions:
#  current shape = (69,)
#  filling on, default _FillValue of 9.969209968386869e+36 used,
#  'height': <class 'netCDF4._netCDF4.Variable'>
#  float64 height(station)
#      long_name: Station height
#      standard_name: height
#      units: m
#  unlimited dimensions:
#  current shape = (69,)
#  filling on, default _FillValue of 9.969209968386869e+36 used,
#  'D1H': <class 'netCDF4._netCDF4.Variable'>
#  float64 D1H(station, time)
#      _FillValue: -9999.0
#      standard_name: rainfall_duration
#      units: min
#      long_name: Rainfall Duration in last Hour
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'dd': <class 'netCDF4._netCDF4.Variable'>
#  float64 dd(station, time)
#      _FillValue: -9999.0
#      standard_name: wind_from_direction
#      units: degree
#      long_name: Wind Direction 10 Min Average with MD
#      comment: MD: Marked Discontinuity is an abrupt change in the 2-minute average wind speed and/or direction. This is defined per WMO and ICAO guidelines as more than 10 knots and/or 30 degrees absolute difference between two successive 2-minute periods  when the wind speed > 10 knots in one or both periods. When a MD is detected, all data older than 2 minutes are excluded from calculation. Variables indicated with MD are therefore calculated based on the samples measured within the previous 2 minutes at minimum, up to the full 10-minute period. Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'dn': <class 'netCDF4._netCDF4.Variable'>
#  float64 dn(station, time)
#      _FillValue: -9999.0
#      standard_name: wind_from_direction
#      units: degree
#      long_name: Wind Direction Sensor 10 Min Minimum with MD
#      comment: MD: Marked Discontinuity is an abrupt change in the 2-minute average wind speed and/or direction. This is defined per WMO and ICAO guidelines as more than 10 knots and/or 30 degrees absolute difference between two successive 2-minute periods  when the wind speed > 10 knots in one or both periods. When a MD is detected, all data older than 2 minutes are excluded from calculation. Variables indicated with MD are therefore calculated based on the samples measured within the previous 2 minutes at minimum, up to the full 10-minute period. Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'dr': <class 'netCDF4._netCDF4.Variable'>
#  float64 dr(station, time)
#      _FillValue: -9999.0
#      standard_name: precipitation_duration
#      units: sec
#      long_name: Precipitation Duration (Rain Gauge) 10 Min Sum
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'dsd': <class 'netCDF4._netCDF4.Variable'>
#  float64 dsd(station, time)
#      _FillValue: -9999.0
#      standard_name: wind_from_direction
#      units: degree
#      long_name: Wind Direction 10 Min Std Dev with MD
#      comment: MD: Marked Discontinuity is an abrupt change in the 2-minute average wind speed and/or direction. This is defined per WMO and ICAO guidelines as more than 10 knots and/or 30 degrees absolute difference between two successive 2-minute periods  when the wind speed > 10 knots in one or both periods. When a MD is detected, all data older than 2 minutes are excluded from calculation. Variables indicated with MD are therefore calculated based on the samples measured within the previous 2 minutes at minimum, up to the full 10-minute period. Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'dx': <class 'netCDF4._netCDF4.Variable'>
#  float64 dx(station, time)
#      _FillValue: -9999.0
#      standard_name: wind_from_direction
#      units: degree
#      long_name: Wind Direction Sensor 10 Min Maximum with MD
#      comment: MD: Marked Discontinuity is an abrupt change in the 2-minute average wind speed and/or direction. This is defined per WMO and ICAO guidelines as more than 10 knots and/or 30 degrees absolute difference between two successive 2-minute periods  when the wind speed > 10 knots in one or both periods. When a MD is detected, all data older than 2 minutes are excluded from calculation. Variables indicated with MD are therefore calculated based on the samples measured within the previous 2 minutes at minimum, up to the full 10-minute period. Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'ff': <class 'netCDF4._netCDF4.Variable'>
#  float64 ff(station, time)
#      _FillValue: -9999.0
#      standard_name: wind_speed
#      units: m s-1
#      long_name: Wind Speed at 10m 10 Min Average with MD
#      comment: MD: Marked Discontinuity is an abrupt change in the 2-minute average wind speed and/or direction. This is defined per WMO and ICAO guidelines as more than 10 knots and/or 30 degrees absolute difference between two successive 2-minute periods  when the wind speed > 10 knots in one or both periods. When a MD is detected, all data older than 2 minutes are excluded from calculation. Variables indicated with MD are therefore calculated based on the samples measured within the previous 2 minutes at minimum, up to the full 10-minute period. Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'ffs': <class 'netCDF4._netCDF4.Variable'>
#  float64 ffs(station, time)
#      _FillValue: -9999.0
#      standard_name: wind_speed_sensor_10_min_average
#      units: m s-1
#      long_name: Wind Speed Sensor 10 Min Average with MD
#      comment: MD: Marked Discontinuity is an abrupt change in the 2-minute average wind speed and/or direction. This is defined per WMO and ICAO guidelines as more than 10 knots and/or 30 degrees absolute difference between two successive 2-minute periods  when the wind speed > 10 knots in one or both periods. When a MD is detected, all data older than 2 minutes are excluded from calculation. Variables indicated with MD are therefore calculated based on the samples measured within the previous 2 minutes at minimum, up to the full 10-minute period. Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'fsd': <class 'netCDF4._netCDF4.Variable'>
#  float64 fsd(station, time)
#      _FillValue: -9999.0
#      standard_name: wind_speed_10_min_std_dev
#      units: m s-1
#      long_name: Wind Speed 10 Min Std Dev with MD
#      comment: MD: Marked Discontinuity is an abrupt change in the 2-minute average wind speed and/or direction. This is defined per WMO and ICAO guidelines as more than 10 knots and/or 30 degrees absolute difference between two successive 2-minute periods  when the wind speed > 10 knots in one or both periods. When a MD is detected, all data older than 2 minutes are excluded from calculation. Variables indicated with MD are therefore calculated based on the samples measured within the previous 2 minutes at minimum, up to the full 10-minute period. Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'fx': <class 'netCDF4._netCDF4.Variable'>
#  float64 fx(station, time)
#      _FillValue: -9999.0
#      standard_name: wind_gust_at_10m_maximum_last_10_min_interval
#      units: m s-1
#      long_name: Wind Gust at 10m Maximum last 10 Min Interval
#      comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'fxs': <class 'netCDF4._netCDF4.Variable'>
#  float64 fxs(station, time)
#      _FillValue: -9999.0
#      standard_name: wind_gust_sensor_maximum_last_10_min_interval
#      units: m s-1
#      long_name: Wind Gust Sensor Maximum last 10 Min Interval
#      comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'gff': <class 'netCDF4._netCDF4.Variable'>
#  float64 gff(station, time)
#      _FillValue: -9999.0
#      standard_name: wind_speed_of_gust
#      units: m s-1
#      long_name: Wind Gust at 10m 10 Min Maximum with MD
#      comment: MD: Marked Discontinuity is an abrupt change in the 2-minute average wind speed and/or direction. This is defined per WMO and ICAO guidelines as more than 10 knots and/or 30 degrees absolute difference between two successive 2-minute periods  when the wind speed > 10 knots in one or both periods. When a MD is detected, all data older than 2 minutes are excluded from calculation. Variables indicated with MD are therefore calculated based on the samples measured within the previous 2 minutes at minimum, up to the full 10-minute period. Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'gffs': <class 'netCDF4._netCDF4.Variable'>
#  float64 gffs(station, time)
#      _FillValue: -9999.0
#      standard_name: wind_speed_of_gust
#      units: m s-1
#      long_name: Wind Gust Sensor 10 Min Maximum with MD
#      comment: MD: Marked Discontinuity is an abrupt change in the 2-minute average wind speed and/or direction. This is defined per WMO and ICAO guidelines as more than 10 knots and/or 30 degrees absolute difference between two successive 2-minute periods  when the wind speed > 10 knots in one or both periods. When a MD is detected, all data older than 2 minutes are excluded from calculation. Variables indicated with MD are therefore calculated based on the samples measured within the previous 2 minutes at minimum, up to the full 10-minute period. Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'h': <class 'netCDF4._netCDF4.Variable'>
#  float64 h(station, time)
#      _FillValue: -9999.0
#      standard_name: cloud_base_altitude
#      units: ft
#      long_name: Cloud Base
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'h1': <class 'netCDF4._netCDF4.Variable'>
#  float64 h1(station, time)
#      _FillValue: -9999.0
#      standard_name: cloud_base_altitude
#      units: ft
#      long_name: Cloud Base First Layer
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'h2': <class 'netCDF4._netCDF4.Variable'>
#  float64 h2(station, time)
#      _FillValue: -9999.0
#      standard_name: cloud_base_altitude
#      units: ft
#      long_name: Cloud Base Second Layer
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'h3': <class 'netCDF4._netCDF4.Variable'>
#  float64 h3(station, time)
#      _FillValue: -9999.0
#      standard_name: cloud_base_altitude
#      units: ft
#      long_name: Cloud Base Third Layer
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'hc': <class 'netCDF4._netCDF4.Variable'>
#  float64 hc(station, time)
#      _FillValue: -9999.0
#      standard_name: cloud_base_altitude
#      units: ft
#      long_name: Cloud Base Ceilometer Algorithm
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'hc1': <class 'netCDF4._netCDF4.Variable'>
#  float64 hc1(station, time)
#      _FillValue: -9999.0
#      standard_name: cloud_base_altitude
#      units: ft
#      long_name: Cloud Base Ceilometer First Layer
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'hc2': <class 'netCDF4._netCDF4.Variable'>
#  float64 hc2(station, time)
#      _FillValue: -9999.0
#      standard_name: cloud_base_altitude
#      units: ft
#      long_name: Cloud Base Ceilometer Second Layer
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'hc3': <class 'netCDF4._netCDF4.Variable'>
#  float64 hc3(station, time)
#      _FillValue: -9999.0
#      standard_name: cloud_base_altitude
#      units: ft
#      long_name: Cloud Base Ceilometer Third Layer
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'n': <class 'netCDF4._netCDF4.Variable'>
#  float64 n(station, time)
#      _FillValue: -9999.0
#      standard_name: cloud_cover
#      units: octa
#      long_name: Total cloud cover
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'n1': <class 'netCDF4._netCDF4.Variable'>
#  float64 n1(station, time)
#      _FillValue: -9999.0
#      standard_name: cloud_cover
#      units: octa
#      long_name: Cloud Amount First Layer
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'n2': <class 'netCDF4._netCDF4.Variable'>
#  float64 n2(station, time)
#      _FillValue: -9999.0
#      standard_name: cloud_cover
#      units: octa
#      long_name: Cloud Amount Second Layer
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'n3': <class 'netCDF4._netCDF4.Variable'>
#  float64 n3(station, time)
#      _FillValue: -9999.0
#      standard_name: cloud_cover
#      units: octa
#      long_name: Cloud Amount Third Layer
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'nc': <class 'netCDF4._netCDF4.Variable'>
#  float64 nc(station, time)
#      _FillValue: -9999.0
#      standard_name: cloud_cover
#      units: octa
#      long_name: Total Cloud Cover Ceilometer
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'nc1': <class 'netCDF4._netCDF4.Variable'>
#  float64 nc1(station, time)
#      _FillValue: -9999.0
#      standard_name: cloud_cover
#      units: octa
#      long_name: Cloud Amount Ceilometer First Layer
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'nc2': <class 'netCDF4._netCDF4.Variable'>
#  float64 nc2(station, time)
#      _FillValue: -9999.0
#      standard_name: cloud_cover
#      units: octa
#      long_name: Cloud Amount Ceilometer Second Layer
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'nc3': <class 'netCDF4._netCDF4.Variable'>
#  float64 nc3(station, time)
#      _FillValue: -9999.0
#      standard_name: cloud_cover
#      units: octa
#      long_name: Cloud Amount Ceilometer Third Layer
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'p0': <class 'netCDF4._netCDF4.Variable'>
#  float64 p0(station, time)
#      _FillValue: -9999.0
#      standard_name: air_pressure_at_station_level
#      units: hPa
#      long_name: Air Pressure at Station Level 1 Min Average
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'pp': <class 'netCDF4._netCDF4.Variable'>
#  float64 pp(station, time)
#      _FillValue: -9999.0
#      standard_name: air_pressure_at_sea_level
#      units: hPa
#      long_name: Air Pressure at Sea Level 1 Min Average
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'pg': <class 'netCDF4._netCDF4.Variable'>
#  float64 pg(station, time)
#      _FillValue: -9999.0
#      standard_name: lwe_precipitation_rate
#      units: mm h-1
#      long_name: Precipitation Intensity (PWS) 10 Min Average
#      comment: Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'pr': <class 'netCDF4._netCDF4.Variable'>
#  float64 pr(station, time)
#      _FillValue: -9999.0
#      standard_name: precipitation_duration
#      units: sec
#      long_name: Precipitation Duration (PWS) 10 Min Sum
#      comment: Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'ps': <class 'netCDF4._netCDF4.Variable'>
#  float64 ps(station, time)
#      _FillValue: -9999.0
#      standard_name: air_pressure_at_sensor_level
#      units: hPa
#      long_name: Air Pressure at Sensor Level 10 Min Average
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'pwc': <class 'netCDF4._netCDF4.Variable'>
#  float64 pwc(station, time)
#      _FillValue: -9999.0
#      standard_name: present_weather
#      units: code
#      long_name: Corrected Precipitation Type 10 Min Maximum
#      comment: KNMI: Handboek waarnemingen. 5.3 PW-code neerslagsoort. https://www.knmi.nl/kennis-en-datacentrum/publicatie/handboek-waarnemingen. Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'Q1H': <class 'netCDF4._netCDF4.Variable'>
#  float64 Q1H(station, time)
#      _FillValue: -9999.0
#      standard_name: global_radiation
#      units: J cm-2
#      long_name: Global Radiation 1 Hour Sum
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'Q24H': <class 'netCDF4._netCDF4.Variable'>
#  float64 Q24H(station, time)
#      _FillValue: -9999.0
#      standard_name: global_radiation
#      units: J cm-2
#      long_name: Global Radiation 24 Hour Sum
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'qg': <class 'netCDF4._netCDF4.Variable'>
#  float64 qg(station, time)
#      _FillValue: -9999.0
#      standard_name: total_downwelling_shortwave_flux_in_air
#      units: W m-2
#      long_name: Global Solar Radiation 10 Min Average
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'qgn': <class 'netCDF4._netCDF4.Variable'>
#  float64 qgn(station, time)
#      _FillValue: -9999.0
#      standard_name: global_solar_radiation
#      units: W m-2
#      long_name: Global Solar Radiation 10 Min Minimum
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'qgx': <class 'netCDF4._netCDF4.Variable'>
#  float64 qgx(station, time)
#      _FillValue: -9999.0
#      standard_name: global_solar_radiation
#      units: W m-2
#      long_name: Global Solar Radiation 10 Min Maximum
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'qnh': <class 'netCDF4._netCDF4.Variable'>
#  float64 qnh(station, time)
#      _FillValue: -9999.0
#      standard_name: qnh_1_min_average
#      units: hPa
#      long_name: QNH 1 Min Average
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'R12H': <class 'netCDF4._netCDF4.Variable'>
#  float64 R12H(station, time)
#      _FillValue: -9999.0
#      standard_name: rainfall_amount
#      units: mm
#      long_name: Rainfall in last 12 Hours
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'R1H': <class 'netCDF4._netCDF4.Variable'>
#  float64 R1H(station, time)
#      _FillValue: -9999.0
#      standard_name: rainfall_amount
#      units: mm
#      long_name: Rainfall in last Hour
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'R24H': <class 'netCDF4._netCDF4.Variable'>
#  float64 R24H(station, time)
#      _FillValue: -9999.0
#      standard_name: rainfall_amount
#      units: mm
#      long_name: Rainfall in last 24 Hours
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'R6H': <class 'netCDF4._netCDF4.Variable'>
#  float64 R6H(station, time)
#      _FillValue: -9999.0
#      standard_name: rainfall_amount
#      units: mm
#      long_name: Rainfall in last 6 Hours
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'rg': <class 'netCDF4._netCDF4.Variable'>
#  float64 rg(station, time)
#      _FillValue: -9999.0
#      standard_name: precipitation_rate
#      units: mm h-1
#      long_name: Precipitation Intensity (Rain Gauge) 10 Min Average
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'rh': <class 'netCDF4._netCDF4.Variable'>
#  float64 rh(station, time)
#      _FillValue: -9999.0
#      standard_name: relative_humidity
#      units: %
#      long_name: Relative Humidity 1.5m 1 Min Average
#      comment: Note: For some locations only rh10 is provided
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'rh10': <class 'netCDF4._netCDF4.Variable'>
#  float64 rh10(station, time)
#      _FillValue: -9999.0
#      standard_name: relative_humidity
#      units: %
#      long_name: Relative Humidity 10 Min Average
#      comment: Note: For this variable the timestamp indicates the middle of the 10 Min interval
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'Sav1H': <class 'netCDF4._netCDF4.Variable'>
#  float64 Sav1H(station, time)
#      _FillValue: -9999.0
#      standard_name: wind_speed
#      units: m s-1
#      long_name: Wind Speed Average last 1 Hour
#      comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At the wind masts of Rijkswaterstaat (mainly in the region Zeeland) and the platforms on the North Sea, the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'Sax1H': <class 'netCDF4._netCDF4.Variable'>
#  float64 Sax1H(station, time)
#      _FillValue: -9999.0
#      standard_name: wind_speed
#      units: m s-1
#      long_name: Wind Speed Maximum last 1 Hour
#      comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At the wind masts of Rijkswaterstaat (mainly in the region Zeeland) and the platforms on the North Sea, the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'Sax3H': <class 'netCDF4._netCDF4.Variable'>
#  float64 Sax3H(station, time)
#      _FillValue: -9999.0
#      standard_name: wind_speed
#      units: m s-1
#      long_name: Wind Speed Maximum last 3 Hours
#      comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At the wind masts of Rijkswaterstaat (mainly in the region Zeeland) and the platforms on the North Sea, the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'Sax6H': <class 'netCDF4._netCDF4.Variable'>
#  float64 Sax6H(station, time)
#      _FillValue: -9999.0
#      standard_name: wind_speed
#      units: m s-1
#      long_name: Wind Speed Maximum last 6 Hours
#      comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At the wind masts of Rijkswaterstaat (mainly in the region Zeeland) and the platforms on the North Sea, the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'sq': <class 'netCDF4._netCDF4.Variable'>
#  float64 sq(station, time)
#      _FillValue: -9999.0
#      standard_name: squall_indicator
#      units: code
#      long_name: Squall Indicator
#      comment: WMO table 4680
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'ss': <class 'netCDF4._netCDF4.Variable'>
#  float64 ss(station, time)
#      _FillValue: -9999.0
#      standard_name: duration_of_sunshine
#      units: min
#      long_name: Sunshine Duration
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'Sx1H': <class 'netCDF4._netCDF4.Variable'>
#  float64 Sx1H(station, time)
#      _FillValue: -9999.0
#      standard_name: wind_gust
#      units: m s-1
#      long_name: Wind Gust Maximum last 1 Hour
#      comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At the wind masts of Rijkswaterstaat (mainly in the region Zeeland) and the platforms on the North Sea, the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'Sx3H': <class 'netCDF4._netCDF4.Variable'>
#  float64 Sx3H(station, time)
#      _FillValue: -9999.0
#      standard_name: wind_gust
#      units: m s-1
#      long_name: Wind Gust Maximum last 3 Hours
#      comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At the wind masts of Rijkswaterstaat (mainly in the region Zeeland) and the platforms on the North Sea, the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'Sx6H': <class 'netCDF4._netCDF4.Variable'>
#  float64 Sx6H(station, time)
#      _FillValue: -9999.0
#      standard_name: wind_gust
#      units: m s-1
#      long_name: Wind Gust Maximum last 6 Hours
#      comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At the wind masts of Rijkswaterstaat (mainly in the region Zeeland) and the platforms on the North Sea, the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  't10': <class 'netCDF4._netCDF4.Variable'>
#  float64 t10(station, time)
#      _FillValue: -9999.0
#      standard_name: ambient_temperature_10_min_average
#      units: degrees Celsius
#      long_name: Ambient Temperature 10 Min Average
#      comment: Note: for this variable the timestamp indicates the middle of the 10 Min interval
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'ta': <class 'netCDF4._netCDF4.Variable'>
#  float64 ta(station, time)
#      _FillValue: -9999.0
#      standard_name: air_temperature
#      units: degrees Celsius
#      long_name: Ambient Temperature 1.5m 1 Min Average
#      comment: Note: For some locations only t10 is provided
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'tb': <class 'netCDF4._netCDF4.Variable'>
#  float64 tb(station, time)
#      _FillValue: -9999.0
#      standard_name: wet_bulb_temperature
#      units: degrees Celsius
#      long_name: Wet Bulb Temperature 1.5m 10 Min Average
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'tb1': <class 'netCDF4._netCDF4.Variable'>
#  float64 tb1(station, time)
#      _FillValue: -9999.0
#      standard_name: soil_temperature
#      units: degrees Celsius
#      long_name: Soil Temperature -5cm 10 Min Average
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'Tb1n6': <class 'netCDF4._netCDF4.Variable'>
#  float64 Tb1n6(station, time)
#      _FillValue: -9999.0
#      standard_name: soil_temperature
#      units: degrees Celsius
#      long_name: Soil Temperature -5cm Minimum last 6 Hours
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'Tb1x6': <class 'netCDF4._netCDF4.Variable'>
#  float64 Tb1x6(station, time)
#      _FillValue: -9999.0
#      standard_name: soil_temperature
#      units: degrees Celsius
#      long_name: Soil Temperature -5cm Maximum last 6 Hours
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'tb2': <class 'netCDF4._netCDF4.Variable'>
#  float64 tb2(station, time)
#      _FillValue: -9999.0
#      standard_name: soil_temperature
#      units: degrees Celsius
#      long_name: Soil Temperature -10cm 10 Min Average
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'Tb2n6': <class 'netCDF4._netCDF4.Variable'>
#  float64 Tb2n6(station, time)
#      _FillValue: -9999.0
#      standard_name: soil_temperature
#      units: degrees Celsius
#      long_name: Soil Temperature -10cm Minimum last 6 Hours
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'Tb2x6': <class 'netCDF4._netCDF4.Variable'>
#  float64 Tb2x6(station, time)
#      _FillValue: -9999.0
#      standard_name: soil_temperature
#      units: degrees Celsius
#      long_name: Soil Temperature -10cm Maximum last 6 Hours
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'tb3': <class 'netCDF4._netCDF4.Variable'>
#  float64 tb3(station, time)
#      _FillValue: -9999.0
#      standard_name: soil_temperature
#      units: degrees Celsius
#      long_name: Soil Temperature -20cm 10 Min Average
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'tb4': <class 'netCDF4._netCDF4.Variable'>
#  float64 tb4(station, time)
#      _FillValue: -9999.0
#      standard_name: soil_temperature
#      units: degrees Celsius
#      long_name: Soil Temperature -50cm 10 Min Average
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'tb5': <class 'netCDF4._netCDF4.Variable'>
#  float64 tb5(station, time)
#      _FillValue: -9999.0
#      standard_name: soil_temperature
#      units: degrees Celsius
#      long_name: Soil Temperature -100cm 10 Min Average
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'td': <class 'netCDF4._netCDF4.Variable'>
#  float64 td(station, time)
#      _FillValue: -9999.0
#      standard_name: dew_point_temperature
#      units: degrees Celsius
#      long_name: Dew Point Temperature 1.5m 1 Min Average
#      comment: Note: For some locations only td10 is provided
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'td10': <class 'netCDF4._netCDF4.Variable'>
#  float64 td10(station, time)
#      _FillValue: -9999.0
#      standard_name: dew_point_temperature
#      units: degrees Celsius
#      long_name: Dew Point Temperature 10 Min Average
#      comment: Note: for this variable the timestamp indicates the middle of the 10 Min interval
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'tg': <class 'netCDF4._netCDF4.Variable'>
#  float64 tg(station, time)
#      _FillValue: -9999.0
#      standard_name: air_temperature
#      units: degrees Celsius
#      long_name: Grass Temperature 10cm 10 Min Average
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'tgn': <class 'netCDF4._netCDF4.Variable'>
#  float64 tgn(station, time)
#      _FillValue: -9999.0
#      standard_name: air_temperature_minimum
#      units: degrees Celsius
#      long_name: Grass Temperature 10cm 10 Min Minimum
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'Tgn12': <class 'netCDF4._netCDF4.Variable'>
#  float64 Tgn12(station, time)
#      _FillValue: -9999.0
#      standard_name: air_temperature_minimum
#      units: degrees Celsius
#      long_name: Grass Temperature Minimum last 12 Hours
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'Tgn14': <class 'netCDF4._netCDF4.Variable'>
#  float64 Tgn14(station, time)
#      _FillValue: -9999.0
#      standard_name: air_temperature_minimum
#      units: degrees Celsius
#      long_name: Grass Temperature Minimum last 14 Hours
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'Tgn6': <class 'netCDF4._netCDF4.Variable'>
#  float64 Tgn6(station, time)
#      _FillValue: -9999.0
#      standard_name: air_temperature_minimum
#      units: degrees Celsius
#      long_name: Grass Temperature Minimum last 6 Hours
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'tn': <class 'netCDF4._netCDF4.Variable'>
#  float64 tn(station, time)
#      _FillValue: -9999.0
#      standard_name: air_temperature_minimum
#      units: degrees Celsius
#      long_name: Ambient Temperature 1.5m 10 Min Minimum
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'Tn12': <class 'netCDF4._netCDF4.Variable'>
#  float64 Tn12(station, time)
#      _FillValue: -9999.0
#      standard_name: air_temperature_minimum
#      units: degrees Celsius
#      long_name: Air Temperature Minimum last 12 Hours
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'Tn14': <class 'netCDF4._netCDF4.Variable'>
#  float64 Tn14(station, time)
#      _FillValue: -9999.0
#      standard_name: air_temperature_minimum
#      units: degrees Celsius
#      long_name: Air Temperature Minimum last 14 Hours
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'Tn6': <class 'netCDF4._netCDF4.Variable'>
#  float64 Tn6(station, time)
#      _FillValue: -9999.0
#      standard_name: air_temperature_minimum
#      units: degrees Celsius
#      long_name: Air Temperature Minimum last 6 Hours
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'tsd': <class 'netCDF4._netCDF4.Variable'>
#  float64 tsd(station, time)
#      _FillValue: -9999.0
#      standard_name: siam_ambient_temperature_10_min_average_std_dev
#      units: degrees Celsius
#      long_name: SIAM Ambient Temperature 10 Min Average Std Dev
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'tx': <class 'netCDF4._netCDF4.Variable'>
#  float64 tx(station, time)
#      _FillValue: -9999.0
#      standard_name: air_temperature_maximum
#      units: degrees Celsius
#      long_name: Ambient Temperature 1.5m 10 Min Maximum
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'Tx12': <class 'netCDF4._netCDF4.Variable'>
#  float64 Tx12(station, time)
#      _FillValue: -9999.0
#      standard_name: air_temperature_maximum
#      units: degrees Celsius
#      long_name: Air Temperature Maximum last 12 Hours
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'Tx24': <class 'netCDF4._netCDF4.Variable'>
#  float64 Tx24(station, time)
#      _FillValue: -9999.0
#      standard_name: air_temperature_maximum
#      units: degrees Celsius
#      long_name: Air Temperature Maximum last 24 Hours
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'Tx6': <class 'netCDF4._netCDF4.Variable'>
#  float64 Tx6(station, time)
#      _FillValue: -9999.0
#      standard_name: air_temperature_maximum
#      units: degrees Celsius
#      long_name: Air Temperature Maximum last 6 Hours
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'vv': <class 'netCDF4._netCDF4.Variable'>
#  float64 vv(station, time)
#      _FillValue: -9999.0
#      standard_name: visibility
#      units: m
#      long_name: Horizontal Visibility 10 Min Average
#      comment: Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'W10': <class 'netCDF4._netCDF4.Variable'>
#  float64 W10(station, time)
#      _FillValue: -9999.0
#      standard_name: past_weather_indicator
#      units: code
#      long_name: Past Weather Indicator
#      comment: WMO table 4680. Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'W10-10': <class 'netCDF4._netCDF4.Variable'>
#  float64 W10-10(station, time)
#      _FillValue: -9999.0
#      standard_name: past_weather_indicator
#      units: code
#      long_name: Past Weather Indicator for Previous 10 Min Interval
#      comment: WMO table 4680. Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'ww': <class 'netCDF4._netCDF4.Variable'>
#  float64 ww(station, time)
#      _FillValue: -9999.0
#      standard_name: wawa_weather_code
#      units: code
#      long_name: wawa Weather Code
#      comment: WMO table 4680. Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'ww-10': <class 'netCDF4._netCDF4.Variable'>
#  float64 ww-10(station, time)
#      _FillValue: -9999.0
#      standard_name: wawa_weather_code
#      units: code
#      long_name: wawa Weather Code for Previous 10 Min Interval
#      comment: WMO table 4680. Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'zm': <class 'netCDF4._netCDF4.Variable'>
#  float64 zm(station, time)
#      _FillValue: -9999.0
#      standard_name: visibility_in_air
#      units: m
#      long_name: Meteorological Optical Range 10 Min Average
#      comment: Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
#  unlimited dimensions:
#  current shape = (69, 1)
#  filling on,
#  'iso_dataset': <class 'netCDF4._netCDF4.Variable'>
#  |S1 iso_dataset()
#      title: KMDS__OPER_P___10M_OBS_L2
#      abstract: Most recent 10 minute in situ observations of the Dutch meteorological observation network
#      status: ongoing
#      type: dataset
#      uid: c3a312e2-2d8f-440b-ae7d-3406c9fe2f77
#      topic: climatology, meteorology, atmosphere
#      keyword: temperature, pressure, relative humidity, visibility, wind speed, wind direction, wind gust
#      max-x: 7.4
#      min-x: -68.5
#      max-y: 55.7
#      min-y: 12.0
#      temporal_extent: 1950-01-01 and ongoing
#      date: 2023-07-01
#      dateType: publication date
#      statement: KNMI collects observations from automatic weather stations situated in the Netherlands and BES islands on locations such as aerodromes and North Sea platforms. In addition, wind data from 5 KNMI wind poles are included. The weather stations report every 10 minutes meteorological parameters such as temperature, relative humidity, wind, air pressure, visibility, precipitation and cloud cover. The number of parameters differs per station.
#      code: 4326
#      codeSpace: EPSG
#      accessConstraints: No limitations
#      useLimitation: No use limitations
#      organisationName_dataset: Royal Netherlands Meteorological Institute (KNMI)
#      email_dataset: opendata@knmi.nl
#      role_dataset: pointOfContact
#      metadata_id: 0ebaef73-6bff-4a25-a86b-6bf53bc4c505
#      organisationName_metadata: Royal Netherlands Meteorological Institute (KNMI)
#      role_metadata: pointOfContact
#      email_metadata: opendata@knmi.nl
#      url_metadata: https://dataplatform.knmi.nl
#      datestamp: 2014-07-23
#      language: eng
#      metadataStandardName: ISO 19115
#      metadataStandardNameVersion: Nederlandse metadatastandaard op ISO 19115 voor geografie 1.2
#  unlimited dimensions:
#  current shape = ()
#  filling on, default _FillValue of  used,
#  'product': <class 'netCDF4._netCDF4.Variable'>
#  |S1 product()
#      units: 1
#      long_name: ADAGUC Data Products Standard
#      ref_doc: ADAGUC Data Products Standard
#      ref_doc_version: 1.1
#      format_version: 1.1
#      originator: Royal Netherlands Meteorological Institute (KNMI)
#      type: P
#      acronym: KMDS__OPER_P___10M_OBS_L2
#      level: L2
#      style: camelCase
#  unlimited dimensions:
#  current shape = ()
#  filling on, default _FillValue of  used,
#  'projection': <class 'netCDF4._netCDF4.Variable'>
#  |S1 projection()
#      EPSG_code: EPSG:4326
#  unlimited dimensions:
#  current shape = ()
#  filling on, default _FillValue of  used,
#  'nhc': <class 'netCDF4._netCDF4.Variable'>
#  |S1 nhc()
#      standard_name: low_and_middle_cloud_amount_ceilometer
#      units: octa
#      long_name: Low and Middle Cloud Amount Ceilometer
#  unlimited dimensions:
#  current shape = ()
#  filling on, default _FillValue of  used,
#  'za': <class 'netCDF4._netCDF4.Variable'>
#  |S1 za()
#      standard_name: background_luminance
#      units: cd m-2
#      long_name: Background Luminance 10 Min Average
#      comment: Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
#  unlimited dimensions:
#  current shape = ()
#  filling on, default _FillValue of  used}

# %%
def print_atters():
    counts = defaultdict(int)
    for file in tqdm(glob.glob("*.nc")):
        db = netCDF4.Dataset(file)
        for key in db.variables.keys():
            counts[key] += 1
        db.close()
    return counts

# %%
def print_atter(attrbitue):
    for file in glob.glob("*.nc"):
        db = netCDF4.Dataset(file)
        print("\n\n",str(file),":")
        try: 
            for key in db.variables.keys():
                print(f"\t{key}: {getattr(db.variables[key],attrbitue)}", end=" ")
        except:
            print("Error")
            print(db.variables)
            return
        finally:
            db.close()

# %%
print_atter("")
# Out:
#  KMDS__OPER_P___10M_OBS_L2_202405171400.nc :
# Error
# {'station': <class 'netCDF4._netCDF4.Variable'>
# vlen station(station)
#     long_name: Station id
#     cf_role: timeseries_id
# vlen data type: <class 'str'>
# unlimited dimensions:
# current shape = (69,), 'time': <class 'netCDF4._netCDF4.Variable'>
# float64 time(time)
#     long_name: time of measurement
#     standard_name: time
#     units: seconds since 1950-01-01 00:00:00
# unlimited dimensions:
# current shape = (1,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'wsi': <class 'netCDF4._netCDF4.Variable'>
# vlen wsi(station)
#     long_name: Station wsi
# vlen data type: <class 'str'>
# unlimited dimensions:
# current shape = (69,), 'stationname': <class 'netCDF4._netCDF4.Variable'>
# vlen stationname(station)
#     long_name: Station name
# vlen data type: <class 'str'>
# unlimited dimensions:
# current shape = (69,), 'lat': <class 'netCDF4._netCDF4.Variable'>
# float64 lat(station)
#     long_name: station  latitude
#     standard_name: latitude
#     units: degrees_north
# unlimited dimensions:
# current shape = (69,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'lon': <class 'netCDF4._netCDF4.Variable'>
# float64 lon(station)
#     long_name: station longitude
#     standard_name: longitude
#     units: degrees_east
# unlimited dimensions:
# current shape = (69,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'height': <class 'netCDF4._netCDF4.Variable'>
# float64 height(station)
#     long_name: Station height
#     standard_name: height
#     units: m
# unlimited dimensions:
# current shape = (69,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'D1H': <class 'netCDF4._netCDF4.Variable'>
# float64 D1H(station, time)
#     _FillValue: -9999.0
#     standard_name: rainfall_duration
#     units: min
#     long_name: Rainfall Duration in last Hour
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'dd': <class 'netCDF4._netCDF4.Variable'>
# float64 dd(station, time)
#     _FillValue: -9999.0
#     standard_name: wind_from_direction
#     units: degree
#     long_name: Wind Direction 10 Min Average with MD
#     comment: MD: Marked Discontinuity is an abrupt change in the 2-minute average wind speed and/or direction. This is defined per WMO and ICAO guidelines as more than 10 knots and/or 30 degrees absolute difference between two successive 2-minute periods  when the wind speed > 10 knots in one or both periods. When a MD is detected, all data older than 2 minutes are excluded from calculation. Variables indicated with MD are therefore calculated based on the samples measured within the previous 2 minutes at minimum, up to the full 10-minute period. Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'dn': <class 'netCDF4._netCDF4.Variable'>
# float64 dn(station, time)
#     _FillValue: -9999.0
#     standard_name: wind_from_direction
#     units: degree
#     long_name: Wind Direction Sensor 10 Min Minimum with MD
#     comment: MD: Marked Discontinuity is an abrupt change in the 2-minute average wind speed and/or direction. This is defined per WMO and ICAO guidelines as more than 10 knots and/or 30 degrees absolute difference between two successive 2-minute periods  when the wind speed > 10 knots in one or both periods. When a MD is detected, all data older than 2 minutes are excluded from calculation. Variables indicated with MD are therefore calculated based on the samples measured within the previous 2 minutes at minimum, up to the full 10-minute period. Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'dr': <class 'netCDF4._netCDF4.Variable'>
# float64 dr(station, time)
#     _FillValue: -9999.0
#     standard_name: precipitation_duration
#     units: sec
#     long_name: Precipitation Duration (Rain Gauge) 10 Min Sum
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'dsd': <class 'netCDF4._netCDF4.Variable'>
# float64 dsd(station, time)
#     _FillValue: -9999.0
#     standard_name: wind_from_direction
#     units: degree
#     long_name: Wind Direction 10 Min Std Dev with MD
#     comment: MD: Marked Discontinuity is an abrupt change in the 2-minute average wind speed and/or direction. This is defined per WMO and ICAO guidelines as more than 10 knots and/or 30 degrees absolute difference between two successive 2-minute periods  when the wind speed > 10 knots in one or both periods. When a MD is detected, all data older than 2 minutes are excluded from calculation. Variables indicated with MD are therefore calculated based on the samples measured within the previous 2 minutes at minimum, up to the full 10-minute period. Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'dx': <class 'netCDF4._netCDF4.Variable'>
# float64 dx(station, time)
#     _FillValue: -9999.0
#     standard_name: wind_from_direction
#     units: degree
#     long_name: Wind Direction Sensor 10 Min Maximum with MD
#     comment: MD: Marked Discontinuity is an abrupt change in the 2-minute average wind speed and/or direction. This is defined per WMO and ICAO guidelines as more than 10 knots and/or 30 degrees absolute difference between two successive 2-minute periods  when the wind speed > 10 knots in one or both periods. When a MD is detected, all data older than 2 minutes are excluded from calculation. Variables indicated with MD are therefore calculated based on the samples measured within the previous 2 minutes at minimum, up to the full 10-minute period. Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'ff': <class 'netCDF4._netCDF4.Variable'>
# float64 ff(station, time)
#     _FillValue: -9999.0
#     standard_name: wind_speed
#     units: m s-1
#     long_name: Wind Speed at 10m 10 Min Average with MD
#     comment: MD: Marked Discontinuity is an abrupt change in the 2-minute average wind speed and/or direction. This is defined per WMO and ICAO guidelines as more than 10 knots and/or 30 degrees absolute difference between two successive 2-minute periods  when the wind speed > 10 knots in one or both periods. When a MD is detected, all data older than 2 minutes are excluded from calculation. Variables indicated with MD are therefore calculated based on the samples measured within the previous 2 minutes at minimum, up to the full 10-minute period. Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'ffs': <class 'netCDF4._netCDF4.Variable'>
# float64 ffs(station, time)
#     _FillValue: -9999.0
#     standard_name: wind_speed_sensor_10_min_average
#     units: m s-1
#     long_name: Wind Speed Sensor 10 Min Average with MD
#     comment: MD: Marked Discontinuity is an abrupt change in the 2-minute average wind speed and/or direction. This is defined per WMO and ICAO guidelines as more than 10 knots and/or 30 degrees absolute difference between two successive 2-minute periods  when the wind speed > 10 knots in one or both periods. When a MD is detected, all data older than 2 minutes are excluded from calculation. Variables indicated with MD are therefore calculated based on the samples measured within the previous 2 minutes at minimum, up to the full 10-minute period. Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'fsd': <class 'netCDF4._netCDF4.Variable'>
# float64 fsd(station, time)
#     _FillValue: -9999.0
#     standard_name: wind_speed_10_min_std_dev
#     units: m s-1
#     long_name: Wind Speed 10 Min Std Dev with MD
#     comment: MD: Marked Discontinuity is an abrupt change in the 2-minute average wind speed and/or direction. This is defined per WMO and ICAO guidelines as more than 10 knots and/or 30 degrees absolute difference between two successive 2-minute periods  when the wind speed > 10 knots in one or both periods. When a MD is detected, all data older than 2 minutes are excluded from calculation. Variables indicated with MD are therefore calculated based on the samples measured within the previous 2 minutes at minimum, up to the full 10-minute period. Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'fx': <class 'netCDF4._netCDF4.Variable'>
# float64 fx(station, time)
#     _FillValue: -9999.0
#     standard_name: wind_gust_at_10m_maximum_last_10_min_interval
#     units: m s-1
#     long_name: Wind Gust at 10m Maximum last 10 Min Interval
#     comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'fxs': <class 'netCDF4._netCDF4.Variable'>
# float64 fxs(station, time)
#     _FillValue: -9999.0
#     standard_name: wind_gust_sensor_maximum_last_10_min_interval
#     units: m s-1
#     long_name: Wind Gust Sensor Maximum last 10 Min Interval
#     comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'gff': <class 'netCDF4._netCDF4.Variable'>
# float64 gff(station, time)
#     _FillValue: -9999.0
#     standard_name: wind_speed_of_gust
#     units: m s-1
#     long_name: Wind Gust at 10m 10 Min Maximum with MD
#     comment: MD: Marked Discontinuity is an abrupt change in the 2-minute average wind speed and/or direction. This is defined per WMO and ICAO guidelines as more than 10 knots and/or 30 degrees absolute difference between two successive 2-minute periods  when the wind speed > 10 knots in one or both periods. When a MD is detected, all data older than 2 minutes are excluded from calculation. Variables indicated with MD are therefore calculated based on the samples measured within the previous 2 minutes at minimum, up to the full 10-minute period. Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'gffs': <class 'netCDF4._netCDF4.Variable'>
# float64 gffs(station, time)
#     _FillValue: -9999.0
#     standard_name: wind_speed_of_gust
#     units: m s-1
#     long_name: Wind Gust Sensor 10 Min Maximum with MD
#     comment: MD: Marked Discontinuity is an abrupt change in the 2-minute average wind speed and/or direction. This is defined per WMO and ICAO guidelines as more than 10 knots and/or 30 degrees absolute difference between two successive 2-minute periods  when the wind speed > 10 knots in one or both periods. When a MD is detected, all data older than 2 minutes are excluded from calculation. Variables indicated with MD are therefore calculated based on the samples measured within the previous 2 minutes at minimum, up to the full 10-minute period. Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'h': <class 'netCDF4._netCDF4.Variable'>
# float64 h(station, time)
#     _FillValue: -9999.0
#     standard_name: cloud_base_altitude
#     units: ft
#     long_name: Cloud Base
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'h1': <class 'netCDF4._netCDF4.Variable'>
# float64 h1(station, time)
#     _FillValue: -9999.0
#     standard_name: cloud_base_altitude
#     units: ft
#     long_name: Cloud Base First Layer
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'h2': <class 'netCDF4._netCDF4.Variable'>
# float64 h2(station, time)
#     _FillValue: -9999.0
#     standard_name: cloud_base_altitude
#     units: ft
#     long_name: Cloud Base Second Layer
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'h3': <class 'netCDF4._netCDF4.Variable'>
# float64 h3(station, time)
#     _FillValue: -9999.0
#     standard_name: cloud_base_altitude
#     units: ft
#     long_name: Cloud Base Third Layer
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'hc': <class 'netCDF4._netCDF4.Variable'>
# float64 hc(station, time)
#     _FillValue: -9999.0
#     standard_name: cloud_base_altitude
#     units: ft
#     long_name: Cloud Base Ceilometer Algorithm
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'hc1': <class 'netCDF4._netCDF4.Variable'>
# float64 hc1(station, time)
#     _FillValue: -9999.0
#     standard_name: cloud_base_altitude
#     units: ft
#     long_name: Cloud Base Ceilometer First Layer
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'hc2': <class 'netCDF4._netCDF4.Variable'>
# float64 hc2(station, time)
#     _FillValue: -9999.0
#     standard_name: cloud_base_altitude
#     units: ft
#     long_name: Cloud Base Ceilometer Second Layer
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'hc3': <class 'netCDF4._netCDF4.Variable'>
# float64 hc3(station, time)
#     _FillValue: -9999.0
#     standard_name: cloud_base_altitude
#     units: ft
#     long_name: Cloud Base Ceilometer Third Layer
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'n': <class 'netCDF4._netCDF4.Variable'>
# float64 n(station, time)
#     _FillValue: -9999.0
#     standard_name: cloud_cover
#     units: octa
#     long_name: Total cloud cover
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'n1': <class 'netCDF4._netCDF4.Variable'>
# float64 n1(station, time)
#     _FillValue: -9999.0
#     standard_name: cloud_cover
#     units: octa
#     long_name: Cloud Amount First Layer
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'n2': <class 'netCDF4._netCDF4.Variable'>
# float64 n2(station, time)
#     _FillValue: -9999.0
#     standard_name: cloud_cover
#     units: octa
#     long_name: Cloud Amount Second Layer
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'n3': <class 'netCDF4._netCDF4.Variable'>
# float64 n3(station, time)
#     _FillValue: -9999.0
#     standard_name: cloud_cover
#     units: octa
#     long_name: Cloud Amount Third Layer
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'nc': <class 'netCDF4._netCDF4.Variable'>
# float64 nc(station, time)
#     _FillValue: -9999.0
#     standard_name: cloud_cover
#     units: octa
#     long_name: Total Cloud Cover Ceilometer
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'nc1': <class 'netCDF4._netCDF4.Variable'>
# float64 nc1(station, time)
#     _FillValue: -9999.0
#     standard_name: cloud_cover
#     units: octa
#     long_name: Cloud Amount Ceilometer First Layer
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'nc2': <class 'netCDF4._netCDF4.Variable'>
# float64 nc2(station, time)
#     _FillValue: -9999.0
#     standard_name: cloud_cover
#     units: octa
#     long_name: Cloud Amount Ceilometer Second Layer
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'nc3': <class 'netCDF4._netCDF4.Variable'>
# float64 nc3(station, time)
#     _FillValue: -9999.0
#     standard_name: cloud_cover
#     units: octa
#     long_name: Cloud Amount Ceilometer Third Layer
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'p0': <class 'netCDF4._netCDF4.Variable'>
# float64 p0(station, time)
#     _FillValue: -9999.0
#     standard_name: air_pressure_at_station_level
#     units: hPa
#     long_name: Air Pressure at Station Level 1 Min Average
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'pp': <class 'netCDF4._netCDF4.Variable'>
# float64 pp(station, time)
#     _FillValue: -9999.0
#     standard_name: air_pressure_at_sea_level
#     units: hPa
#     long_name: Air Pressure at Sea Level 1 Min Average
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'pg': <class 'netCDF4._netCDF4.Variable'>
# float64 pg(station, time)
#     _FillValue: -9999.0
#     standard_name: lwe_precipitation_rate
#     units: mm h-1
#     long_name: Precipitation Intensity (PWS) 10 Min Average
#     comment: Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'pr': <class 'netCDF4._netCDF4.Variable'>
# float64 pr(station, time)
#     _FillValue: -9999.0
#     standard_name: precipitation_duration
#     units: sec
#     long_name: Precipitation Duration (PWS) 10 Min Sum
#     comment: Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'ps': <class 'netCDF4._netCDF4.Variable'>
# float64 ps(station, time)
#     _FillValue: -9999.0
#     standard_name: air_pressure_at_sensor_level
#     units: hPa
#     long_name: Air Pressure at Sensor Level 10 Min Average
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'pwc': <class 'netCDF4._netCDF4.Variable'>
# float64 pwc(station, time)
#     _FillValue: -9999.0
#     standard_name: present_weather
#     units: code
#     long_name: Corrected Precipitation Type 10 Min Maximum
#     comment: KNMI: Handboek waarnemingen. 5.3 PW-code neerslagsoort. https://www.knmi.nl/kennis-en-datacentrum/publicatie/handboek-waarnemingen. Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'Q1H': <class 'netCDF4._netCDF4.Variable'>
# float64 Q1H(station, time)
#     _FillValue: -9999.0
#     standard_name: global_radiation
#     units: J cm-2
#     long_name: Global Radiation 1 Hour Sum
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'Q24H': <class 'netCDF4._netCDF4.Variable'>
# float64 Q24H(station, time)
#     _FillValue: -9999.0
#     standard_name: global_radiation
#     units: J cm-2
#     long_name: Global Radiation 24 Hour Sum
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'qg': <class 'netCDF4._netCDF4.Variable'>
# float64 qg(station, time)
#     _FillValue: -9999.0
#     standard_name: total_downwelling_shortwave_flux_in_air
#     units: W m-2
#     long_name: Global Solar Radiation 10 Min Average
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'qgn': <class 'netCDF4._netCDF4.Variable'>
# float64 qgn(station, time)
#     _FillValue: -9999.0
#     standard_name: global_solar_radiation
#     units: W m-2
#     long_name: Global Solar Radiation 10 Min Minimum
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'qgx': <class 'netCDF4._netCDF4.Variable'>
# float64 qgx(station, time)
#     _FillValue: -9999.0
#     standard_name: global_solar_radiation
#     units: W m-2
#     long_name: Global Solar Radiation 10 Min Maximum
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'qnh': <class 'netCDF4._netCDF4.Variable'>
# float64 qnh(station, time)
#     _FillValue: -9999.0
#     standard_name: qnh_1_min_average
#     units: hPa
#     long_name: QNH 1 Min Average
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'R12H': <class 'netCDF4._netCDF4.Variable'>
# float64 R12H(station, time)
#     _FillValue: -9999.0
#     standard_name: rainfall_amount
#     units: mm
#     long_name: Rainfall in last 12 Hours
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'R1H': <class 'netCDF4._netCDF4.Variable'>
# float64 R1H(station, time)
#     _FillValue: -9999.0
#     standard_name: rainfall_amount
#     units: mm
#     long_name: Rainfall in last Hour
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'R24H': <class 'netCDF4._netCDF4.Variable'>
# float64 R24H(station, time)
#     _FillValue: -9999.0
#     standard_name: rainfall_amount
#     units: mm
#     long_name: Rainfall in last 24 Hours
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'R6H': <class 'netCDF4._netCDF4.Variable'>
# float64 R6H(station, time)
#     _FillValue: -9999.0
#     standard_name: rainfall_amount
#     units: mm
#     long_name: Rainfall in last 6 Hours
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'rg': <class 'netCDF4._netCDF4.Variable'>
# float64 rg(station, time)
#     _FillValue: -9999.0
#     standard_name: precipitation_rate
#     units: mm h-1
#     long_name: Precipitation Intensity (Rain Gauge) 10 Min Average
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'rh': <class 'netCDF4._netCDF4.Variable'>
# float64 rh(station, time)
#     _FillValue: -9999.0
#     standard_name: relative_humidity
#     units: %
#     long_name: Relative Humidity 1.5m 1 Min Average
#     comment: Note: For some locations only rh10 is provided
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'rh10': <class 'netCDF4._netCDF4.Variable'>
# float64 rh10(station, time)
#     _FillValue: -9999.0
#     standard_name: relative_humidity
#     units: %
#     long_name: Relative Humidity 10 Min Average
#     comment: Note: For this variable the timestamp indicates the middle of the 10 Min interval
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'Sav1H': <class 'netCDF4._netCDF4.Variable'>
# float64 Sav1H(station, time)
#     _FillValue: -9999.0
#     standard_name: wind_speed
#     units: m s-1
#     long_name: Wind Speed Average last 1 Hour
#     comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At the wind masts of Rijkswaterstaat (mainly in the region Zeeland) and the platforms on the North Sea, the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'Sax1H': <class 'netCDF4._netCDF4.Variable'>
# float64 Sax1H(station, time)
#     _FillValue: -9999.0
#     standard_name: wind_speed
#     units: m s-1
#     long_name: Wind Speed Maximum last 1 Hour
#     comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At the wind masts of Rijkswaterstaat (mainly in the region Zeeland) and the platforms on the North Sea, the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'Sax3H': <class 'netCDF4._netCDF4.Variable'>
# float64 Sax3H(station, time)
#     _FillValue: -9999.0
#     standard_name: wind_speed
#     units: m s-1
#     long_name: Wind Speed Maximum last 3 Hours
#     comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At the wind masts of Rijkswaterstaat (mainly in the region Zeeland) and the platforms on the North Sea, the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'Sax6H': <class 'netCDF4._netCDF4.Variable'>
# float64 Sax6H(station, time)
#     _FillValue: -9999.0
#     standard_name: wind_speed
#     units: m s-1
#     long_name: Wind Speed Maximum last 6 Hours
#     comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At the wind masts of Rijkswaterstaat (mainly in the region Zeeland) and the platforms on the North Sea, the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'sq': <class 'netCDF4._netCDF4.Variable'>
# float64 sq(station, time)
#     _FillValue: -9999.0
#     standard_name: squall_indicator
#     units: code
#     long_name: Squall Indicator
#     comment: WMO table 4680
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'ss': <class 'netCDF4._netCDF4.Variable'>
# float64 ss(station, time)
#     _FillValue: -9999.0
#     standard_name: duration_of_sunshine
#     units: min
#     long_name: Sunshine Duration
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'Sx1H': <class 'netCDF4._netCDF4.Variable'>
# float64 Sx1H(station, time)
#     _FillValue: -9999.0
#     standard_name: wind_gust
#     units: m s-1
#     long_name: Wind Gust Maximum last 1 Hour
#     comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At the wind masts of Rijkswaterstaat (mainly in the region Zeeland) and the platforms on the North Sea, the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'Sx3H': <class 'netCDF4._netCDF4.Variable'>
# float64 Sx3H(station, time)
#     _FillValue: -9999.0
#     standard_name: wind_gust
#     units: m s-1
#     long_name: Wind Gust Maximum last 3 Hours
#     comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At the wind masts of Rijkswaterstaat (mainly in the region Zeeland) and the platforms on the North Sea, the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'Sx6H': <class 'netCDF4._netCDF4.Variable'>
# float64 Sx6H(station, time)
#     _FillValue: -9999.0
#     standard_name: wind_gust
#     units: m s-1
#     long_name: Wind Gust Maximum last 6 Hours
#     comment: Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At the wind masts of Rijkswaterstaat (mainly in the region Zeeland) and the platforms on the North Sea, the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 't10': <class 'netCDF4._netCDF4.Variable'>
# float64 t10(station, time)
#     _FillValue: -9999.0
#     standard_name: ambient_temperature_10_min_average
#     units: degrees Celsius
#     long_name: Ambient Temperature 10 Min Average
#     comment: Note: for this variable the timestamp indicates the middle of the 10 Min interval
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'ta': <class 'netCDF4._netCDF4.Variable'>
# float64 ta(station, time)
#     _FillValue: -9999.0
#     standard_name: air_temperature
#     units: degrees Celsius
#     long_name: Ambient Temperature 1.5m 1 Min Average
#     comment: Note: For some locations only t10 is provided
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'tb': <class 'netCDF4._netCDF4.Variable'>
# float64 tb(station, time)
#     _FillValue: -9999.0
#     standard_name: wet_bulb_temperature
#     units: degrees Celsius
#     long_name: Wet Bulb Temperature 1.5m 10 Min Average
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'tb1': <class 'netCDF4._netCDF4.Variable'>
# float64 tb1(station, time)
#     _FillValue: -9999.0
#     standard_name: soil_temperature
#     units: degrees Celsius
#     long_name: Soil Temperature -5cm 10 Min Average
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'Tb1n6': <class 'netCDF4._netCDF4.Variable'>
# float64 Tb1n6(station, time)
#     _FillValue: -9999.0
#     standard_name: soil_temperature
#     units: degrees Celsius
#     long_name: Soil Temperature -5cm Minimum last 6 Hours
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'Tb1x6': <class 'netCDF4._netCDF4.Variable'>
# float64 Tb1x6(station, time)
#     _FillValue: -9999.0
#     standard_name: soil_temperature
#     units: degrees Celsius
#     long_name: Soil Temperature -5cm Maximum last 6 Hours
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'tb2': <class 'netCDF4._netCDF4.Variable'>
# float64 tb2(station, time)
#     _FillValue: -9999.0
#     standard_name: soil_temperature
#     units: degrees Celsius
#     long_name: Soil Temperature -10cm 10 Min Average
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'Tb2n6': <class 'netCDF4._netCDF4.Variable'>
# float64 Tb2n6(station, time)
#     _FillValue: -9999.0
#     standard_name: soil_temperature
#     units: degrees Celsius
#     long_name: Soil Temperature -10cm Minimum last 6 Hours
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'Tb2x6': <class 'netCDF4._netCDF4.Variable'>
# float64 Tb2x6(station, time)
#     _FillValue: -9999.0
#     standard_name: soil_temperature
#     units: degrees Celsius
#     long_name: Soil Temperature -10cm Maximum last 6 Hours
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'tb3': <class 'netCDF4._netCDF4.Variable'>
# float64 tb3(station, time)
#     _FillValue: -9999.0
#     standard_name: soil_temperature
#     units: degrees Celsius
#     long_name: Soil Temperature -20cm 10 Min Average
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'tb4': <class 'netCDF4._netCDF4.Variable'>
# float64 tb4(station, time)
#     _FillValue: -9999.0
#     standard_name: soil_temperature
#     units: degrees Celsius
#     long_name: Soil Temperature -50cm 10 Min Average
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'tb5': <class 'netCDF4._netCDF4.Variable'>
# float64 tb5(station, time)
#     _FillValue: -9999.0
#     standard_name: soil_temperature
#     units: degrees Celsius
#     long_name: Soil Temperature -100cm 10 Min Average
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'td': <class 'netCDF4._netCDF4.Variable'>
# float64 td(station, time)
#     _FillValue: -9999.0
#     standard_name: dew_point_temperature
#     units: degrees Celsius
#     long_name: Dew Point Temperature 1.5m 1 Min Average
#     comment: Note: For some locations only td10 is provided
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'td10': <class 'netCDF4._netCDF4.Variable'>
# float64 td10(station, time)
#     _FillValue: -9999.0
#     standard_name: dew_point_temperature
#     units: degrees Celsius
#     long_name: Dew Point Temperature 10 Min Average
#     comment: Note: for this variable the timestamp indicates the middle of the 10 Min interval
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'tg': <class 'netCDF4._netCDF4.Variable'>
# float64 tg(station, time)
#     _FillValue: -9999.0
#     standard_name: air_temperature
#     units: degrees Celsius
#     long_name: Grass Temperature 10cm 10 Min Average
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'tgn': <class 'netCDF4._netCDF4.Variable'>
# float64 tgn(station, time)
#     _FillValue: -9999.0
#     standard_name: air_temperature_minimum
#     units: degrees Celsius
#     long_name: Grass Temperature 10cm 10 Min Minimum
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'Tgn12': <class 'netCDF4._netCDF4.Variable'>
# float64 Tgn12(station, time)
#     _FillValue: -9999.0
#     standard_name: air_temperature_minimum
#     units: degrees Celsius
#     long_name: Grass Temperature Minimum last 12 Hours
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'Tgn14': <class 'netCDF4._netCDF4.Variable'>
# float64 Tgn14(station, time)
#     _FillValue: -9999.0
#     standard_name: air_temperature_minimum
#     units: degrees Celsius
#     long_name: Grass Temperature Minimum last 14 Hours
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'Tgn6': <class 'netCDF4._netCDF4.Variable'>
# float64 Tgn6(station, time)
#     _FillValue: -9999.0
#     standard_name: air_temperature_minimum
#     units: degrees Celsius
#     long_name: Grass Temperature Minimum last 6 Hours
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'tn': <class 'netCDF4._netCDF4.Variable'>
# float64 tn(station, time)
#     _FillValue: -9999.0
#     standard_name: air_temperature_minimum
#     units: degrees Celsius
#     long_name: Ambient Temperature 1.5m 10 Min Minimum
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'Tn12': <class 'netCDF4._netCDF4.Variable'>
# float64 Tn12(station, time)
#     _FillValue: -9999.0
#     standard_name: air_temperature_minimum
#     units: degrees Celsius
#     long_name: Air Temperature Minimum last 12 Hours
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'Tn14': <class 'netCDF4._netCDF4.Variable'>
# float64 Tn14(station, time)
#     _FillValue: -9999.0
#     standard_name: air_temperature_minimum
#     units: degrees Celsius
#     long_name: Air Temperature Minimum last 14 Hours
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'Tn6': <class 'netCDF4._netCDF4.Variable'>
# float64 Tn6(station, time)
#     _FillValue: -9999.0
#     standard_name: air_temperature_minimum
#     units: degrees Celsius
#     long_name: Air Temperature Minimum last 6 Hours
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'tsd': <class 'netCDF4._netCDF4.Variable'>
# float64 tsd(station, time)
#     _FillValue: -9999.0
#     standard_name: siam_ambient_temperature_10_min_average_std_dev
#     units: degrees Celsius
#     long_name: SIAM Ambient Temperature 10 Min Average Std Dev
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'tx': <class 'netCDF4._netCDF4.Variable'>
# float64 tx(station, time)
#     _FillValue: -9999.0
#     standard_name: air_temperature_maximum
#     units: degrees Celsius
#     long_name: Ambient Temperature 1.5m 10 Min Maximum
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'Tx12': <class 'netCDF4._netCDF4.Variable'>
# float64 Tx12(station, time)
#     _FillValue: -9999.0
#     standard_name: air_temperature_maximum
#     units: degrees Celsius
#     long_name: Air Temperature Maximum last 12 Hours
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'Tx24': <class 'netCDF4._netCDF4.Variable'>
# float64 Tx24(station, time)
#     _FillValue: -9999.0
#     standard_name: air_temperature_maximum
#     units: degrees Celsius
#     long_name: Air Temperature Maximum last 24 Hours
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'Tx6': <class 'netCDF4._netCDF4.Variable'>
# float64 Tx6(station, time)
#     _FillValue: -9999.0
#     standard_name: air_temperature_maximum
#     units: degrees Celsius
#     long_name: Air Temperature Maximum last 6 Hours
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'vv': <class 'netCDF4._netCDF4.Variable'>
# float64 vv(station, time)
#     _FillValue: -9999.0
#     standard_name: visibility
#     units: m
#     long_name: Horizontal Visibility 10 Min Average
#     comment: Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'W10': <class 'netCDF4._netCDF4.Variable'>
# float64 W10(station, time)
#     _FillValue: -9999.0
#     standard_name: past_weather_indicator
#     units: code
#     long_name: Past Weather Indicator
#     comment: WMO table 4680. Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'W10-10': <class 'netCDF4._netCDF4.Variable'>
# float64 W10-10(station, time)
#     _FillValue: -9999.0
#     standard_name: past_weather_indicator
#     units: code
#     long_name: Past Weather Indicator for Previous 10 Min Interval
#     comment: WMO table 4680. Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'ww': <class 'netCDF4._netCDF4.Variable'>
# float64 ww(station, time)
#     _FillValue: -9999.0
#     standard_name: wawa_weather_code
#     units: code
#     long_name: wawa Weather Code
#     comment: WMO table 4680. Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'ww-10': <class 'netCDF4._netCDF4.Variable'>
# float64 ww-10(station, time)
#     _FillValue: -9999.0
#     standard_name: wawa_weather_code
#     units: code
#     long_name: wawa Weather Code for Previous 10 Min Interval
#     comment: WMO table 4680. Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'zm': <class 'netCDF4._netCDF4.Variable'>
# float64 zm(station, time)
#     _FillValue: -9999.0
#     standard_name: visibility_in_air
#     units: m
#     long_name: Meteorological Optical Range 10 Min Average
#     comment: Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
# unlimited dimensions:
# current shape = (69, 1)
# filling on, 'iso_dataset': <class 'netCDF4._netCDF4.Variable'>
# |S1 iso_dataset()
#     title: KMDS__OPER_P___10M_OBS_L2
#     abstract: Most recent 10 minute in situ observations of the Dutch meteorological observation network
#     status: ongoing
#     type: dataset
#     uid: c3a312e2-2d8f-440b-ae7d-3406c9fe2f77
#     topic: climatology, meteorology, atmosphere
#     keyword: temperature, pressure, relative humidity, visibility, wind speed, wind direction, wind gust
#     max-x: 7.4
#     min-x: -68.5
#     max-y: 55.7
#     min-y: 12.0
#     temporal_extent: 1950-01-01 and ongoing
#     date: 2023-07-01
#     dateType: publication date
#     statement: KNMI collects observations from automatic weather stations situated in the Netherlands and BES islands on locations such as aerodromes and North Sea platforms. In addition, wind data from 5 KNMI wind poles are included. The weather stations report every 10 minutes meteorological parameters such as temperature, relative humidity, wind, air pressure, visibility, precipitation and cloud cover. The number of parameters differs per station.
#     code: 4326
#     codeSpace: EPSG
#     accessConstraints: No limitations
#     useLimitation: No use limitations
#     organisationName_dataset: Royal Netherlands Meteorological Institute (KNMI)
#     email_dataset: opendata@knmi.nl
#     role_dataset: pointOfContact
#     metadata_id: 0ebaef73-6bff-4a25-a86b-6bf53bc4c505
#     organisationName_metadata: Royal Netherlands Meteorological Institute (KNMI)
#     role_metadata: pointOfContact
#     email_metadata: opendata@knmi.nl
#     url_metadata: https://dataplatform.knmi.nl
#     datestamp: 2014-07-23
#     language: eng
#     metadataStandardName: ISO 19115
#     metadataStandardNameVersion: Nederlandse metadatastandaard op ISO 19115 voor geografie 1.2
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of  used, 'product': <class 'netCDF4._netCDF4.Variable'>
# |S1 product()
#     units: 1
#     long_name: ADAGUC Data Products Standard
#     ref_doc: ADAGUC Data Products Standard
#     ref_doc_version: 1.1
#     format_version: 1.1
#     originator: Royal Netherlands Meteorological Institute (KNMI)
#     type: P
#     acronym: KMDS__OPER_P___10M_OBS_L2
#     level: L2
#     style: camelCase
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of  used, 'projection': <class 'netCDF4._netCDF4.Variable'>
# |S1 projection()
#     EPSG_code: EPSG:4326
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of  used, 'nhc': <class 'netCDF4._netCDF4.Variable'>
# |S1 nhc()
#     standard_name: low_and_middle_cloud_amount_ceilometer
#     units: octa
#     long_name: Low and Middle Cloud Amount Ceilometer
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of  used, 'za': <class 'netCDF4._netCDF4.Variable'>
# |S1 za()
#     standard_name: background_luminance
#     units: cd m-2
#     long_name: Background Luminance 10 Min Average
#     comment: Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of  used}

# %%
from tomark import Tomark

def get_nc_filename() -> str:
    return next(glob.iglob("*.nc"))

def make_table():
    file = get_nc_filename()
    db = netCDF4.Dataset(file)
    result = []
    for key, value in db.variables.items():
        data =  db.variables[key]
        try:
            long_name = data.long_name
        except:
            long_name = None
        try:
            units = data.units
        except:
            units  = None
        try:
            print(key, data.comment)
        except:
            print(key,"no comment")
        # quantization
        row = {"name": data.name, "Long name": long_name, "size": data.size, "dimensions": data.dimensions, "units": units, "type": data.datatype,"scale": data.scale}
        result.append(row)
    db.close()
    return result



docs = make_table()
with open("table.table.md", "w+") as table_output:
    table_str = Tomark.table(docs)
    # print(table_str)
    table_output.write(table_str)
import os
# Out:
# station no comment
# time no comment
# wsi no comment
# stationname no comment
# lat no comment
# lon no comment
# height no comment
# D1H no comment
# dd MD: Marked Discontinuity is an abrupt change in the 2-minute average wind speed and/or direction. This is defined per WMO and ICAO guidelines as more than 10 knots and/or 30 degrees absolute difference between two successive 2-minute periods  when the wind speed > 10 knots in one or both periods. When a MD is detected, all data older than 2 minutes are excluded from calculation. Variables indicated with MD are therefore calculated based on the samples measured within the previous 2 minutes at minimum, up to the full 10-minute period. Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# dn MD: Marked Discontinuity is an abrupt change in the 2-minute average wind speed and/or direction. This is defined per WMO and ICAO guidelines as more than 10 knots and/or 30 degrees absolute difference between two successive 2-minute periods  when the wind speed > 10 knots in one or both periods. When a MD is detected, all data older than 2 minutes are excluded from calculation. Variables indicated with MD are therefore calculated based on the samples measured within the previous 2 minutes at minimum, up to the full 10-minute period. Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# dr no comment
# dsd MD: Marked Discontinuity is an abrupt change in the 2-minute average wind speed and/or direction. This is defined per WMO and ICAO guidelines as more than 10 knots and/or 30 degrees absolute difference between two successive 2-minute periods  when the wind speed > 10 knots in one or both periods. When a MD is detected, all data older than 2 minutes are excluded from calculation. Variables indicated with MD are therefore calculated based on the samples measured within the previous 2 minutes at minimum, up to the full 10-minute period. Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# dx MD: Marked Discontinuity is an abrupt change in the 2-minute average wind speed and/or direction. This is defined per WMO and ICAO guidelines as more than 10 knots and/or 30 degrees absolute difference between two successive 2-minute periods  when the wind speed > 10 knots in one or both periods. When a MD is detected, all data older than 2 minutes are excluded from calculation. Variables indicated with MD are therefore calculated based on the samples measured within the previous 2 minutes at minimum, up to the full 10-minute period. Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# ff MD: Marked Discontinuity is an abrupt change in the 2-minute average wind speed and/or direction. This is defined per WMO and ICAO guidelines as more than 10 knots and/or 30 degrees absolute difference between two successive 2-minute periods  when the wind speed > 10 knots in one or both periods. When a MD is detected, all data older than 2 minutes are excluded from calculation. Variables indicated with MD are therefore calculated based on the samples measured within the previous 2 minutes at minimum, up to the full 10-minute period. Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# ffs MD: Marked Discontinuity is an abrupt change in the 2-minute average wind speed and/or direction. This is defined per WMO and ICAO guidelines as more than 10 knots and/or 30 degrees absolute difference between two successive 2-minute periods  when the wind speed > 10 knots in one or both periods. When a MD is detected, all data older than 2 minutes are excluded from calculation. Variables indicated with MD are therefore calculated based on the samples measured within the previous 2 minutes at minimum, up to the full 10-minute period. Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# fsd MD: Marked Discontinuity is an abrupt change in the 2-minute average wind speed and/or direction. This is defined per WMO and ICAO guidelines as more than 10 knots and/or 30 degrees absolute difference between two successive 2-minute periods  when the wind speed > 10 knots in one or both periods. When a MD is detected, all data older than 2 minutes are excluded from calculation. Variables indicated with MD are therefore calculated based on the samples measured within the previous 2 minutes at minimum, up to the full 10-minute period. Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# fx Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# fxs Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# gff MD: Marked Discontinuity is an abrupt change in the 2-minute average wind speed and/or direction. This is defined per WMO and ICAO guidelines as more than 10 knots and/or 30 degrees absolute difference between two successive 2-minute periods  when the wind speed > 10 knots in one or both periods. When a MD is detected, all data older than 2 minutes are excluded from calculation. Variables indicated with MD are therefore calculated based on the samples measured within the previous 2 minutes at minimum, up to the full 10-minute period. Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# gffs MD: Marked Discontinuity is an abrupt change in the 2-minute average wind speed and/or direction. This is defined per WMO and ICAO guidelines as more than 10 knots and/or 30 degrees absolute difference between two successive 2-minute periods  when the wind speed > 10 knots in one or both periods. When a MD is detected, all data older than 2 minutes are excluded from calculation. Variables indicated with MD are therefore calculated based on the samples measured within the previous 2 minutes at minimum, up to the full 10-minute period. Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At certain wind masts of Rijkswaterstaat (06209, 06225, 06229, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331) and the platforms on the North Sea (06201, 06203, 06204, 06205, 06207, 06208, 06211, 06214, 06239, 06252, 06320, 06321, 06317), the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# h no comment
# h1 no comment
# h2 no comment
# h3 no comment
# hc no comment
# hc1 no comment
# hc2 no comment
# hc3 no comment
# n no comment
# n1 no comment
# n2 no comment
# n3 no comment
# nc no comment
# nc1 no comment
# nc2 no comment
# nc3 no comment
# p0 no comment
# pp no comment
# pg Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
# pr Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
# ps no comment
# pwc KNMI: Handboek waarnemingen. 5.3 PW-code neerslagsoort. https://www.knmi.nl/kennis-en-datacentrum/publicatie/handboek-waarnemingen. Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
# Q1H no comment
# Q24H no comment
# qg no comment
# qgn no comment
# qgx no comment
# qnh no comment
# R12H no comment
# R1H no comment
# R24H no comment
# R6H no comment
# rg no comment
# rh Note: For some locations only rh10 is provided
# rh10 Note: For this variable the timestamp indicates the middle of the 10 Min interval
# Sav1H Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At the wind masts of Rijkswaterstaat (mainly in the region Zeeland) and the platforms on the North Sea, the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# Sax1H Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At the wind masts of Rijkswaterstaat (mainly in the region Zeeland) and the platforms on the North Sea, the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# Sax3H Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At the wind masts of Rijkswaterstaat (mainly in the region Zeeland) and the platforms on the North Sea, the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# Sax6H Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At the wind masts of Rijkswaterstaat (mainly in the region Zeeland) and the platforms on the North Sea, the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# sq WMO table 4680
# ss no comment
# Sx1H Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At the wind masts of Rijkswaterstaat (mainly in the region Zeeland) and the platforms on the North Sea, the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# Sx3H Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At the wind masts of Rijkswaterstaat (mainly in the region Zeeland) and the platforms on the North Sea, the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# Sx6H Note: For wind observations of stations 06209, 06285, 06308, 06312, 06313, 06315, 06316, 06324, 06331 the timestamp indicates the middle of the interval. At other locations the timestamp of the wind observations indicates the end of the interval. The wind sensors at stations 06225, 06229, 06242, 06258, 06260, 06310, 06330 and 06343 are located at different heights above the surrounding terrain than the standard 10m height, and the 10m wind speeds (ff, fx, gff) are copies of the wind speed measured at the height of the wind sensor (ffs, fxs, gffs respectively). The standard deviation of the wind speed (fsd) is not corrected for non-standard measurement height. At the wind masts of Rijkswaterstaat (mainly in the region Zeeland) and the platforms on the North Sea, the wind speed is also measured at heights above mean sea level differing from 10m but the 10m wind speeds are estimates of the wind speed that would have been measured at 10m height, based on the sensor height measurements.
# t10 Note: for this variable the timestamp indicates the middle of the 10 Min interval
# ta Note: For some locations only t10 is provided
# tb no comment
# tb1 no comment
# Tb1n6 no comment
# Tb1x6 no comment
# tb2 no comment
# Tb2n6 no comment
# Tb2x6 no comment
# tb3 no comment
# tb4 no comment
# tb5 no comment
# td Note: For some locations only td10 is provided
# td10 Note: for this variable the timestamp indicates the middle of the 10 Min interval
# tg no comment
# tgn no comment
# Tgn12 no comment
# Tgn14 no comment
# Tgn6 no comment
# tn no comment
# Tn12 no comment
# Tn14 no comment
# Tn6 no comment
# tsd no comment
# tx no comment
# Tx12 no comment
# Tx24 no comment
# Tx6 no comment
# vv Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
# W10 WMO table 4680. Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
# W10-10 WMO table 4680. Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
# ww WMO table 4680. Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
# ww-10 WMO table 4680. Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
# zm Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.
# iso_dataset no comment
# product no comment
# projection no comment
# nhc no comment
# za Note: The sensor is not installed at equal heights at all types of measurement sites: At 'AWS' sites the device is installed at 1.80m. At 'AWS/Aerodrome' and 'Mistpost' (note that this includes site Voorschoten (06215) which is 'AWS/Mistpost') the device is installed at 2.50m elevation. Exceptions are Berkhout AWS (06249), De Bilt AWS (06260) and Twenthe AWS (06290) where the sensor is installed at 2.50m.

# %%
def iter_nc_files():
    for file in glob.iglob("*.nc"):
        db = netCDF4.Dataset(file)
        try:
            yield db
        finally:
            db.close()

def make_unitset():
    result = set()
    for db in iter_nc_files():
        for variable in db.variables.values():
            print(dir(variable))
            unit = variable.units if hasattr(variable, "units") else None
            if unit is not None: 
                result.add(unit)
    return result

make_unitset()
# Out:
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ...
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# ['Conventions', '__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__orthogonal_indexing__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_close', '_close_mem', '_enddef', '_getname', '_grpid', '_isopen', '_ncstring_attrs__', '_redef', 'close', 'cmptypes', 'comment', 'createCompoundType', 'createDimension', 'createEnumType', 'createGroup', 'createVLType', 'createVariable', 'data_model', 'delncattr', 'dimensions', 'disk_format', 'enumtypes', 'featureType', 'file_format', 'filepath', 'fromcdl', 'get_variables_by_attributes', 'getncattr', 'groups', 'has_blosc_filter', 'has_bzip2_filter', 'has_szip_filter', 'has_zstd_filter', 'history', 'institution', 'isopen', 'keepweakref', 'name', 'ncattrs', 'parent', 'path', 'references', 'renameAttribute', 'renameDimension', 'renameGroup', 'renameVariable', 'set_always_mask', 'set_auto_chartostring', 'set_auto_mask', 'set_auto_maskandscale', 'set_auto_scale', 'set_fill_off', 'set_fill_on', 'set_ncstring_attrs', 'setncattr', 'setncattr_string', 'setncatts', 'source', 'sync', 'title', 'tocdl', 'variables', 'vltypes']
# set()

# %%
from torch.utils.data import Dataset

# %%
from typing import Literal, List

ValidKeys = Literal["name", "lx"]

class CustomImageDataset(Dataset):
    def __init__(self, keys: List[ValidKeys]):
        ## Load the data from the nc files. But these would be combined into non nc files
        self.transform = transform
        self.target_transform = target_transform

    def __len__(self):
        return len(self.img_labels)

    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx, 0])
        image = read_image(img_path)
        label = self.img_labels.iloc[idx, 1]
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        return image, label

# %%
for db in iter_nc_files():
    if "comment" in db.variables:
        continue
    comment = db.variables.get("comment")
    if comment:
        print(comment)
        break
